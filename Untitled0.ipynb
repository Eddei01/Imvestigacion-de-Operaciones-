# %% [markdown]
# <a href="https://colab.research.google.com/github/Eddei01/Imvestigacion-de-Operaciones-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Gráfica de una parabola $x^2$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(15,5,50)
plt.plot(x**2)
